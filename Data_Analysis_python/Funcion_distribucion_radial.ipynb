# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib notebook

# Parameters for beautifulize the plots
plt.rcParams.update({'mathtext.default':  'regular' })
sns.set(context='paper',style="whitegrid",font='Times New Roman', font_scale=1.2)

# %%
with open ('./FeOH3-rdf0300.dat', 'r') as fout:
    value=fout.read()
text=value.split('\n20000 100\n')[1]

# %%
fdr = pd.DataFrame([i.split(' ')for i in text.split('\n')][:-1],dtype=float,
                   columns = ['Num','D',
                              'gr11','int_gr11',
                              'gr22','int_gr22',
                              'gr33', 'int_gr33',
                              'gr12','int_gr12',
                              'gr13','int_gr13',
                              'gr23', 'int_gr23',])

fig=plt.figure()
plt.plot(fdr.D, fdr.gr33, label='Fe-Fe')
plt.plot(fdr.D, fdr.gr11, label='H-H')
plt.plot(fdr.D, fdr.gr22, label='O-O')
plt.legend()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig=plt.figure()
plt.plot(fdr.D, fdr.gr12, label='H-O')
plt.plot(fdr.D, fdr.gr13, label='H-Fe')
plt.plot(fdr.D, fdr.gr23, label='O-Fe')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#plt.plot(fdr.D, fdr.int_gr33)
plt.plot(fdr.D, fdr.int_gr11)
plt.plot(fdr.D, fdr.int_gr22)

#plt.plot(fdr.D, fdr.int_gr12)
#plt.plot(fdr.D, fdr.int_gr13)
#plt.plot(fdr.D, fdr.int_gr23)
plt.show()

# %%
np.random.random(10)
d=np.linspace(fdr.D)
# Out:
# array([[ 0.05      ,  0.15      ,  0.25      , ...,  9.75      ,
#          9.85      ,  9.95      ],
#        [ 0.25306122,  0.35102041,  0.44897959, ...,  9.75510204,
#          9.85306122,  9.95102041],
#        [ 0.45612245,  0.55204082,  0.64795918, ...,  9.76020408,
#          9.85612245,  9.95204082],
#        ...,
#        [ 9.59387755,  9.59795918,  9.60204082, ...,  9.98979592,
#          9.99387755,  9.99795918],
#        [ 9.79693878,  9.79897959,  9.80102041, ...,  9.99489796,
#          9.99693878,  9.99897959],
#        [10.        , 10.        , 10.        , ..., 10.        ,
#         10.        , 10.        ]])
