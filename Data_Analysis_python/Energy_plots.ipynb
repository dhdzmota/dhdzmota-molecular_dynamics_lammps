# %%
# Data processing libraries
import pandas as pd

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Parameters for beautifulize the plots
plt.rcParams.update({'mathtext.default':  'regular' })
sns.set(context='paper',style="whitegrid",font='Times New Roman', font_scale=1.2)

# %%
# Environment
# %matplotlib notebook

# Read the simulation data
with open('../LAMMPS_FILES/2.txt','r') as fout:
    value = fout.read()
    
# Clean the values and generate a dataframe
v = value.split('Mbytes\n')[1].split('\nLoop time')[0].split('\n')
lista=[]
for i in v:
    i=i.split(' ')
    while '' in i:
        i.remove('')
    lista.append(i)

#df = pd.DataFrame(lista[1:],columns=lista[0], dtype=float)
#df2= pd.DataFrame(lista[1:],columns=lista[0], dtype=float)
df3 = pd.DataFrame(lista[1:],columns=lista[0], dtype=float)

# Obtain some insights
#df['K'] = df.TotEng - df.E_pair
#df['time'] = df.Step*0.07
#df2['K'] = df2.TotEng - df2.E_pair
#df2['time'] = df2.Step*0.07
#df3['K'] = df3.TotEng - df3.E_pair
#df3['time'] = df3.Step*0.07

# Plot the energies
upper_limit=50000
plt.plot(df.time[0:upper_limit],df.E_pair[0:upper_limit], label='Energia Potencial')
plt.plot(df2.time[0:upper_limit],df2.E_pair[0:upper_limit], label='Energia Potencial')
plt.plot(df3.time[0:upper_limit],df3.E_pair[0:upper_limit], label='Energia Potencial')

#plt.plot(df.time[0:upper_limit],df.TotEng[0:upper_limit], label='Energia Total')


#plt.plot(df.time[0:upper_limit],df.K[0:upper_limit], label='Energia Cinética',c='g')

# Add labels, and legends 
plt.xlabel('Tiempo (fs)')
plt.ylabel('Energía')
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
